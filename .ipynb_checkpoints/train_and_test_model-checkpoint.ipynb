# %%
from predictive_tool import fare_prediction_class

# %%
#install dependencies
pip install -r requirements.txt

# %%
class_obj=fare_prediction_class()

# %%
# EDA
class_obj.eda('fare_amount') # add any column from the raw training data
# Out:
# count    75000.000000
# mean        19.365893
# std         17.488843
# min          0.010000
# 25%          8.600000
# 50%         12.800000
# 75%         21.900000
# max        233.300000
# Name: fare_amount, dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %%
# Feature Engineering
train_data=class_obj.feature_engineering()

# %%
class_obj.corr()
# Out:
#                          trip_distance  passenger_count  trip_duration_min  \
# trip_distance                 1.000000         0.030464           0.429825
# passenger_count               0.030464         1.000000          -0.001106
# trip_duration_min             0.429825        -0.001106           1.000000
# pickup_hour                  -0.015554         0.029115          -0.022991
# avg_speed_miles_per_min       0.173212         0.009086           0.016929
# fare_amount                   0.919807         0.050353           0.434327
#
#                          pickup_hour  avg_speed_miles_per_min  fare_amount
# trip_distance              -0.015554                 0.173212     0.919807
# passenger_count             0.029115                 0.009086     0.050353
# trip_duration_min          -0.022991                 0.016929     0.434327
# pickup_hour                 1.000000                -0.019148    -0.010232
# ...

# %%
# Model training
class_obj.model_training()

# %%
# Generating predictions
class_obj.predictions()
